# %% [markdown]
# # World Happiness Analysis by Country

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st
import seaborn as sns

# %%
# Show path to csv files
original_data = "Resources/completData.csv"

# Read csv files through Pandas
data = pd.read_csv(original_data)

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank 2015  Happiness Score 2015  \
# 0  Switzerland  Western Europe                  1.0                 7.587
# 1      Iceland  Western Europe                  2.0                 7.561
# 2      Denmark  Western Europe                  3.0                 7.527
# 3       Norway  Western Europe                  4.0                 7.522
# 4       Canada   North America                  5.0                 7.427
#
#    Economy (GDP per Capita) 2015  Family 2015  Health (Life Expectancy) 2015  \
# 0                          1.397        1.350                          0.941
# 1                          1.302        1.402                          0.948
# 2                          1.325        1.361                          0.875
# 3                          1.459        1.331                          0.885
# 4                          1.326        1.323                          0.906
#
#    Freedom 2015  Trust (Government Corruption) 2015  Generosity 2015  ...  \
# 0         0.666                               0.420            0.297  ...
# 1         0.629                               0.141            0.436  ...
# 2         0.649                               0.484            0.341  ...
# 3         0.670                               0.365            0.347  ...
# 4         0.633                               0.330            0.458  ...
#
#    Trust (Government Corruption) 2018  Generosity 2018  Happiness Rank 2019  \
# 0                               0.357            0.256                  6.0
# 1                               0.138            0.353                  4.0
# 2                               0.408            0.284                  2.0
# 3                               0.340            0.286                  3.0
# 4                               0.291            0.321                  9.0
#
#    Happiness Score 2019  Economy (GDP per Capita) 2019  Family 2019  \
# 0                 7.480                          1.452        1.526
# 1                 7.494                          1.380        1.624
# 2                 7.600                          1.383        1.573
# 3                 7.554                          1.488        1.582
# 4                 7.278                          1.365        1.505
#
#    Health (Life Expectancy) 2019  Freedom 2019  \
# 0                          1.052         0.572
# 1                          1.026         0.591
# 2                          0.996         0.592
# 3                          1.028         0.603
# 4                          1.039         0.584
#
#    Trust (Government Corruption) 2019  Generosity 2019
# 0                               0.343            0.263
# 1                               0.118            0.354
# 2                               0.410            0.252
# 3                               0.341            0.271
# 4                               0.308            0.285
#
# [5 rows x 42 columns]

# %%
# Group data with Country as index
complet_data_Summary = data.groupby("Country")
complet_data_Summary.mean()
# Out:
#              Happiness Rank 2015  Happiness Score 2015  \
# Country
# Afghanistan                153.0                 3.575
# Albania                     95.0                 4.959
# Algeria                     68.0                 5.605
# Argentina                   30.0                 6.574
# Armenia                    127.0                 4.350
# ...                          ...                   ...
# Venezuela                   23.0                 6.810
# Vietnam                     75.0                 5.360
# Yemen                      136.0                 4.077
# Zambia                      85.0                 5.129
# Zimbabwe                   115.0                 4.610
#
#              Economy (GDP per Capita) 2015  Family 2015  \
# Country
# Afghanistan                          0.320        0.303
# Albania                              0.879        0.804
# Algeria                              0.939        1.078
# Argentina                            1.054        1.248
# Armenia                              0.768        0.777
# ...                                    ...          ...
# Venezuela                            1.044        1.256
# Vietnam                              0.632        0.912
# Yemen                                0.546        0.681
# Zambia                               0.470        0.916
# Zimbabwe                             0.271        1.033
#
#              Health (Life Expectancy) 2015  Freedom 2015  \
# Country
# Afghanistan                          0.303         0.234
# Albania                              0.813         0.357
# Algeria                              0.618         0.286
# Argentina                            0.787         0.450
# Armenia                              0.730         0.198
# ...                                    ...           ...
# Venezuela                            0.721         0.429
# Vietnam                              0.747         0.594
# Yemen                                0.401         0.356
# Zambia                               0.299         0.488
# Zimbabwe                             0.335         0.259
#
#              Trust (Government Corruption) 2015  Generosity 2015  \
# Country
# Afghanistan                               0.097            0.365
# Albania                                   0.064            0.143
# Algeria                                   0.174            0.078
# Argentina                                 0.085            0.115
# Armenia                                   0.039            0.079
# ...                                         ...              ...
# Venezuela                                 0.111            0.058
# Vietnam                                   0.104            0.169
# Yemen                                     0.079            0.091
# Zambia                                    0.125            0.196
# Zimbabwe                                  0.081            0.190
#
#              Happiness Rank 2016  Happiness Score 2016  ...  \
# Country                                                 ...
# Afghanistan                154.0                 3.360  ...
# Albania                    109.0                 4.655  ...
# Algeria                     38.0                 6.355  ...
# Argentina                   26.0                 6.650  ...
# Armenia                    121.0                 4.360  ...
# ...                          ...                   ...  ...
# Venezuela                   44.0                 6.084  ...
# Vietnam                     96.0                 5.061  ...
# Yemen                      147.0                 3.724  ...
# Zambia                     106.0                 4.795  ...
# Zimbabwe                   131.0                 4.193  ...
#
#              Trust (Government Corruption) 2018  Generosity 2018  \
# Country
# Afghanistan                               0.036            0.191
# Albania                                   0.032            0.149
# Algeria                                   0.135            0.055
# Argentina                                 0.054            0.062
# Armenia                                   0.028            0.077
# ...                                         ...              ...
# Venezuela                                 0.052            0.056
# Vietnam                                   0.079            0.177
# Yemen                                     0.064            0.083
# Zambia                                    0.082            0.221
# Zimbabwe                                  0.099            0.132
#
#              Happiness Rank 2019  Happiness Score 2019  \
# Country
# Afghanistan                154.0                 3.203
# Albania                    107.0                 4.719
# Algeria                     88.0                 5.211
# Argentina                   47.0                 6.086
# Armenia                    116.0                 4.559
# ...                          ...                   ...
# Venezuela                  108.0                 4.707
# Vietnam                     94.0                 5.175
# Yemen                      151.0                 3.380
# Zambia                     138.0                 4.107
# Zimbabwe                   146.0                 3.663
#
#              Economy (GDP per Capita) 2019  Family 2019  \
# Country
# Afghanistan                          0.350        0.517
# Albania                              0.947        0.848
# Algeria                              1.002        1.160
# Argentina                            1.092        1.432
# Armenia                              0.850        1.055
# ...                                    ...          ...
# Venezuela                            0.960        1.427
# Vietnam                              0.741        1.346
# Yemen                                0.287        1.163
# Zambia                               0.578        1.058
# Zimbabwe                             0.366        1.114
#
#              Health (Life Expectancy) 2019  Freedom 2019  \
# Country
# Afghanistan                          0.361         0.000
# Albania                              0.874         0.383
# Algeria                              0.785         0.086
# Argentina                            0.881         0.471
# Armenia                              0.815         0.283
# ...                                    ...           ...
# Venezuela                            0.805         0.154
# Vietnam                              0.851         0.543
# Yemen                                0.463         0.143
# Zambia                               0.426         0.431
# Zimbabwe                             0.433         0.361
#
#              Trust (Government Corruption) 2019  Generosity 2019
# Country
# Afghanistan                               0.025            0.158
# Albania                                   0.027            0.178
# Algeria                                   0.114            0.073
# Argentina                                 0.050            0.066
# Armenia                                   0.064            0.095
# ...                                         ...              ...
# Venezuela                                 0.047            0.064
# Vietnam                                   0.073            0.147
# Yemen                                     0.077            0.108
# Zambia                                    0.087            0.247
# Zimbabwe                                  0.089            0.151
#
# [140 rows x 40 columns]

# %%
list(data.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank 2015',
#  'Happiness Score 2015',
#  'Economy (GDP per Capita) 2015',
#  'Family 2015',
#  'Health (Life Expectancy) 2015',
#  'Freedom 2015',
#  'Trust (Government Corruption) 2015',
#  'Generosity 2015',
#  'Happiness Rank 2016',
#  'Happiness Score 2016',
#  'Economy (GDP per Capita) 2016',
#  'Family 2016',
#  'Health (Life Expectancy) 2016',
#  'Freedom 2016',
#  'Trust (Government Corruption) 2016',
#  'Generosity 2016',
#  'Happiness Rank 2017',
#  'Happiness Score 2017',
#  'Economy (GDP per Capita) 2017',
#  'Family 2017',
#  'Health (Life Expectancy) 2017',
#  'Freedom 2017',
#  'Trust (Government Corruption) 2017',
#  'Generosity 2017',
#  'Happiness Rank 2018',
#  'Happiness Score 2018',
#  'Economy (GDP per Capita) 2018',
#  'Family 2018',
#  'Health (Life Expectancy) 2018',
#  'Freedom 2018',
#  'Trust (Government Corruption) 2018',
#  'Generosity 2018',
#  'Happiness Rank 2019',
#  'Happiness Score 2019',
#  'Economy (GDP per Capita) 2019',
#  'Family 2019',
#  'Health (Life Expectancy) 2019',
#  'Freedom 2019',
#  'Trust (Government Corruption) 2019',
#  'Generosity 2019']

# %% [markdown]
# ## Trust (Government Corruption)

# %%
# Summary of Trust (Government Corruption) per year
Trust_df = data[["Country", "Trust (Government Corruption) 2015", "Trust (Government Corruption) 2016", "Trust (Government Corruption) 2017", "Trust (Government Corruption) 2018", "Trust (Government Corruption) 2019"]]
Trust_df = Trust_df.groupby("Country")
Trust_df.mean()

#Find the averages of the data
GOV_df = Trust_df.mean().reset_index()
GOV_df["Gov Trust Average"] = GOV_df.mean(axis=1)
GOV_df

# Filter the DataFrame down only to those columns to chart
GOV_plot = GOV_df[["Country", "Gov Trust Average"]]

# Set the index to be "Country" so they will be used as labels
GOV_plot = GOV_plot.set_index("Country")
GOV_plot.head(200)
# Out:
#              Gov Trust Average
# Country
# Afghanistan             0.0580
# Albania                 0.0432
# Algeria                 0.1462
# Argentina               0.0644
# Armenia                 0.0388
# ...                        ...
# Venezuela               0.0714
# Vietnam                 0.0920
# Yemen                   0.0672
# Zambia                  0.0974
# Zimbabwe                0.0900
#
# [140 rows x 1 columns]

# %%
# List top 10 Countries with the highest average Government Trust Average

highest_10_GOV = GOV_plot.nlargest(10, ['Gov Trust Average'])
highest_10_GOV
# Out:
#              Gov Trust Average
# Country
# Rwanda                  0.4734
# Singapore               0.4672
# Denmark                 0.4296
# New Zealand             0.4000
# Finland                 0.3986
# Sweden                  0.3974
# Switzerland             0.3798
# Qatar                   0.3558
# Norway                  0.3440
# Luxembourg              0.3374

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
highest_10_GOV.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Government Trust Score Per Country")

plt.show()
plt.tight_layout()

# %%
# List top 10 Countries with the lowest average Government Trust Average

lowest_10_GOV = GOV_plot.nsmallest(10, ['Gov Trust Average'])
lowest_10_GOV
# Out:
#                         Gov Trust Average
# Country
# Bosnia and Herzegovina             0.0016
# Romania                            0.0046
# Bulgaria                           0.0078
# Moldova                            0.0090
# Indonesia                          0.0128
# Portugal                           0.0168
# Lithuania                          0.0176
# Ukraine                            0.0184
# Slovakia                           0.0230
# Italy                              0.0282

# %% [markdown]
# ## Generocity

# %%
# Summary of Generocity per year
Generocity_df = data[["Country", "Generosity 2015", "Generosity 2016", "Generosity 2017", "Generosity 2018", "Generosity 2019"]]
Generocity_df = Generocity_df.groupby("Country")
Generocity_df.mean()

#Find the averages of the data
Gen_df = Generocity_df.mean().reset_index()
Gen_df["Generocity Average"] = Gen_df.mean(axis=1)
Gen_df

# Filter the DataFrame down only to those columns to chart
Gen_plot = Gen_df[["Country", "Generocity Average"]]

# Set the index to be "Country" so they will be used as labels
Gen_plot = Gen_plot.set_index("Country")
Gen_plot.head()
# Out:
#              Generocity Average
# Country
# Afghanistan              0.2678
# Albania                  0.1678
# Algeria                  0.0690
# Argentina                0.0924
# Armenia                  0.0824

# %%
# List top 10 Countries with the highest average Generocity Average
highest_10_generocity = Gen_plot.nlargest(10, ['Generocity Average'])
highest_10_generocity
# Out:
#                 Generocity Average
# Country
# Myanmar                     0.7236
# Indonesia                   0.5348
# Thailand                    0.4916
# Malta                       0.4812
# Haiti                       0.4484
# Bhutan                      0.4346
# New Zealand                 0.4328
# Syria                       0.4314
# United Kingdom              0.4248
# Iceland                     0.4192

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
highest_10_generocity.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Generocity Score Per Country")

plt.show()
plt.tight_layout()

# %%
# List top 10 Countries with the lowest average Generocity Average
lowest_10_generocity = Gen_plot.nsmallest(10, ['Generocity Average'])
lowest_10_generocity
# Out:
#             Generocity Average
# Country
# Greece                  0.0000
# Lithuania               0.0250
# Morocco                 0.0414
# Russia                  0.0456
# Azerbaijan              0.0490
# China                   0.0496
# Gabon                   0.0498
# Tunisia                 0.0504
# Georgia                 0.0516
# Venezuela               0.0572

# %% [markdown]
# ## Health (Life Expectancy)

# %%
# Summary of Health per year
Health_df = data[["Country", "Health (Life Expectancy) 2015","Health (Life Expectancy) 2016", "Health (Life Expectancy) 2017", "Health (Life Expectancy) 2018", "Health (Life Expectancy) 2019"]]
Health_df = Health_df.groupby("Country")
Health_df.mean()

#Find the averages of the data
Heal_df = Health_df.mean().reset_index()
Heal_df["Health Average"] = Heal_df.mean(axis=1)
Heal_df

# Filter the DataFrame down only to those columns to chart
Health_plot = Heal_df[["Country", "Health Average"]]

# Set the index to be "Country" so they will be used as labels
Health_plot = Health_plot.set_index("Country")
Health_plot.head()
# Out:
#              Health Average
# Country
# Afghanistan          0.2546
# Albania              0.7876
# Algeria              0.6652
# Argentina            0.7608
# Armenia              0.6980

# %%
# List top 10 Countries with the highest average Health Average
highest_10_health = Health_plot.nlargest(10, ['Health Average'])
highest_10_health
# Out:
#              Health Average
# Country
# Singapore            1.0140
# Japan                0.9790
# Spain                0.9502
# South Korea          0.9484
# Italy                0.9286
# Switzerland          0.9282
# Iceland              0.9178
# France               0.9162
# Australia            0.9146
# Cyprus               0.9138

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
highest_10_health.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Life Expectancy Per Country")

plt.show()
plt.tight_layout()

# %%
# List top 10 Countries with the lowest average Health Average
lowest_10_health = Health_plot.nsmallest(10, ['Health Average'])
lowest_10_health
# Out:
#                   Health Average
# Country
# Sierra Leone              0.0496
# Chad                      0.0948
# Ivory Coast               0.1116
# Nigeria                   0.1122
# Mali                      0.1996
# Cameroon                  0.2014
# Congo (Kinshasa)          0.2076
# Burundi                   0.2116
# Guinea                    0.2416
# Afghanistan               0.2546

# %% [markdown]
# ## Family

# %%
# Summary of Family per year
Family_df = data[["Country", "Family 2015", "Family 2016", "Family 2017", "Family 2018", "Family 2019"]]
Family_df = Family_df.groupby("Country")
Family_df.mean()

#Find the averages of the data
Fam_df = Family_df.mean().reset_index()
Fam_df["Family Average"] = Fam_df.mean(axis=1)
Fam_df

# Filter the DataFrame down only to those columns to chart
Family_plot = Fam_df[["Country", "Family Average"]]

# Set the index to be "Country" so they will be used as labels
Family_plot = Family_plot.set_index("Country")
Family_plot.head()
# Out:
#              Family Average
# Country
# Afghanistan          0.4098
# Albania              0.7550
# Algeria              1.0742
# Argentina            1.3308
# Armenia              0.8908

# %%
# List top 10 Countries with the highest average Family Average
highest_10_Family = Family_plot.nlargest(10, ['Family Average'])
highest_10_Family
# Out:
#              Family Average
# Country
# Iceland              1.4928
# Denmark              1.4478
# Ireland              1.4450
# New Zealand          1.4398
# Finland              1.4344
# Uzbekistan           1.4340
# Norway               1.4312
# Switzerland          1.4174
# Australia            1.4090
# Spain                1.3994

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
highest_10_Family.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average GDP Per Country")

plt.show()
plt.tight_layout()

# %%
# List top 10 Countries with the lowest average Family Average
lowest_10_Family = Family_plot.nsmallest(10, ['Family Average'])
lowest_10_Family
# Out:
#              Family Average
# Country
# Togo                 0.3236
# Benin                0.3404
# Syria                0.3560
# Afghanistan          0.4098
# Malawi               0.4344
# Burundi              0.4708
# Georgia              0.4814
# India                0.5880
# Pakistan             0.6088
# Haiti                0.6162

# %% [markdown]
# ## Freedom

# %%
#Summary of Freedom score
Freedom_df = data[["Country", "Freedom 2015", "Freedom 2016", "Freedom 2017", "Freedom 2018", "Freedom 2019"]]
Freedom_df = Freedom_df.groupby("Country")
Freedom_df.mean()

#Find the averages of the data
Free_df = Freedom_df.mean().reset_index()
Free_df["Freedom Average"] = Free_df.mean(axis=1)
Free_df

#sort data in ascending order based on Average
Free_df.sort_values(by=['Freedom Average'], inplace=True, ascending=False)
Free_df

# Filter the DataFrame down only to those columns to chart
Freedom_plot = Free_df[["Country", "Freedom Average"]]

# Set the index to be "Country" so they will be used as labels
Freedom_plot = Freedom_plot.set_index("Country")
Freedom_plot.head()
# Out:
#             Freedom Average
# Country
# Uzbekistan           0.6558
# Norway               0.6380
# Cambodia             0.6378
# Denmark              0.6258
# Finland              0.6216

# %%
# List top 10 Countries with the highest average Freedom Average
highest_10_Freedom = Freedom_plot.nlargest(10, ['Freedom Average'])
highest_10_Freedom
# Out:
#              Freedom Average
# Country
# Uzbekistan            0.6558
# Norway                0.6380
# Cambodia              0.6378
# Denmark               0.6258
# Finland               0.6216
# Switzerland           0.6208
# Iceland               0.6180
# New Zealand           0.6176
# Sweden                0.6176
# Canada                0.6110

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
highest_10_Freedom.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Freedom Score Per Country")

plt.show()
plt.tight_layout()

# %%
# List top 10 Countries with the lowest average Freedom Average
lowest_10_Freedom = Freedom_plot.nsmallest(10, ['Freedom Average'])
lowest_10_Freedom
# Out:
#                         Freedom Average
# Country
# Syria                            0.0818
# Greece                           0.0858
# Haiti                            0.0892
# Burundi                          0.1014
# Afghanistan                      0.1178
# Mauritania                       0.1320
# Ukraine                          0.1688
# Bosnia and Herzegovina           0.1766
# Madagascar                       0.1774
# Chad                             0.1776

# %% [markdown]
# ## Happiness Score

# %%
# Summary of Happiness Score per year
Happiness_df = data[["Country", "Happiness Score 2015", "Happiness Score 2016", "Happiness Score 2017", "Happiness Score 2018", "Happiness Score 2019"]]
Happiness_df = Happiness_df.groupby("Country")
Happiness_df.mean()

#Find the averages of the data
Happ_df = Happiness_df.mean().reset_index()
Happ_df["Happiness Average"] = Happ_df.mean(axis=1)
Happ_df

# Filter the DataFrame down only to those columns to chart
Happiness_plot = Happ_df[["Country", "Happiness Average"]]

# Set the index to be "Country" so they will be used as labels
Happiness_plot = Happiness_plot.set_index("Country")
Happiness_plot.head()
# Out:
#              Happiness Average
# Country
# Afghanistan             3.5128
# Albania                 4.7126
# Algeria                 5.6676
# Argentina               6.4594
# Armenia                 4.3932

# %%
# List top 10 Countries with the highest average Happiness Average
highest_10_Happiness = Happiness_plot.nlargest(10, ['Happiness Average'])
highest_10_Happiness
# Out:
#              Happiness Average
# Country
# Denmark                 7.5460
# Norway                  7.5410
# Finland                 7.5378
# Switzerland             7.5114
# Iceland                 7.5110
# Netherlands             7.4046
# Canada                  7.3506
# Sweden                  7.3192
# New Zealand             7.3130
# Australia               7.2762

# %%
# Use DataFrame.plot() in order to create a bar chart of the data

#highest_10_Happiness.plot(kind="bar", figsize=(5,3))
highest_10_Happiness.plot(kind="bar", figsize=(7,5))

plt.ylim(7.2, 7.6)
#plt.yticks(np.arange(7.2, 7.6, step=1))

# Set a title for the chart
plt.title("Average Happiness Score Per Country")

# Save and Show plot
plt.tight_layout()
plt.savefig("Images/AverageHappiness_Country.png")
plt.show()

# %%
#highest_10_Happiness.head(10)
df=highest_10_Happiness.reset_index()
df
# Out:
#        Country  Happiness Average
# 0      Denmark             7.5460
# 1       Norway             7.5410
# 2      Finland             7.5378
# 3  Switzerland             7.5114
# 4      Iceland             7.5110
# 5  Netherlands             7.4046
# 6       Canada             7.3506
# 7       Sweden             7.3192
# 8  New Zealand             7.3130
# 9    Australia             7.2762

# %%
labels = df["Country"]
values = df["Happiness Average"]

# Change the bar colors here
plt.bar(labels, values, color=['red', 'red', 'red', 'red', 'red', 'red', 'blue','red','green','green'])

plt.xticks(rotation=90)
plt.ylim(7.2, 7.6)

plt.title("Average Happiness Score Per Country")
plt.ylabel('Happiness Score (Avg)')
plt.xlabel('Country')

# Save and Show plot
plt.tight_layout()
plt.savefig("Images/AverageHappiness_Country.png")
plt.show()

# %%
# List top 10 Countries with the lowest average Happiness Average
lowest_10_Happiness = Happiness_plot.nsmallest(10, ['Happiness Average'])
lowest_10_Happiness
# Out:
#              Happiness Average
# Country
# Burundi                 3.0790
# Syria                   3.2922
# Rwanda                  3.4386
# Tanzania                3.4660
# Afghanistan             3.5128
# Togo                    3.5442
# Yemen                   3.6258
# Madagascar              3.7454
# Botswana                3.8300
# Liberia                 3.8392

# %% [markdown]
# ## Economy (GDP per Capita)

# %%
# Summary of Happiness per year
Economy_df = data[["Country", "Economy (GDP per Capita) 2015","Economy (GDP per Capita) 2016", "Economy (GDP per Capita) 2017", "Economy (GDP per Capita) 2018", "Economy (GDP per Capita) 2019" ]]
Economy_df = Economy_df.groupby("Country")
Economy_df.mean()

#Find the averages of the data
Econ_df = Economy_df.mean().reset_index()
Econ_df["Economy GDP Average"] = Econ_df.mean(axis=1)
Econ_df

# Filter the DataFrame down only to those columns to chart
Economy_plot = Econ_df[["Country", "Economy GDP Average"]]

# Set the index to be "Country" so they will be used as labels
Economy_plot = Economy_plot.set_index("Country")
Economy_plot.head()
Economy_plot.head()
# Out:
#              Economy GDP Average
# Country
# Afghanistan               0.3570
# Albania                   0.9386
# Algeria                   1.0130
# Argentina                 1.1110
# Armenia                   0.8392

# %%
# List top 10 Countries with the highest average Economy GDP Averag
highest_10_Economy = Economy_plot.nlargest(10, ['Economy GDP Average'])
highest_10_Economy
# Out:
#                Economy GDP Average
# Country
# Qatar                       1.7436
# Luxembourg                  1.6378
# Singapore                   1.5922
# Kuwait                      1.5556
# Norway                      1.5192
# Switzerland                 1.4722
# Ireland                     1.4604
# United States               1.4560
# Saudi Arabia                1.4396
# Netherlands                 1.4110

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
highest_10_Economy.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average GDP Per Country")

plt.show()
plt.tight_layout()

# %%
# List top 10 Countries with the lowest average Economy GDP Averag
lowest_10_Economy = Economy_plot.nsmallest(10, ['Economy GDP Average'])
lowest_10_Economy
# Out:
#                   Economy GDP Average
# Country
# Burundi                        0.0624
# Congo (Kinshasa)               0.0624
# Liberia                        0.0892
# Niger                          0.1266
# Malawi                         0.1426
# Togo                           0.2658
# Madagascar                     0.2660
# Guinea                         0.2734
# Ethiopia                       0.2934
# Burkina Faso                   0.3146

# %% [markdown]
# ## Merge Averages to one dataframe

# %%
# Merge all average columns together and order in top 10 Countries with highest Happiness Average
# Merging Data on Country
Comparison_data = pd.merge(GOV_plot, Gen_plot, on = ["Country"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Health_plot, on = ["Country"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Family_plot, on = ["Country"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Economy_plot, on = ["Country"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Freedom_plot, on = ["Country"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Happiness_plot, on = ["Country"], how = "outer")

top_ten_Comparison_data = Comparison_data.nlargest(10, ['Happiness Average'])
top_ten_Comparison_data
# Out:
#              Gov Trust Average  Generocity Average  Health Average  \
# Country
# Denmark                 0.4296              0.3188          0.8654
# Norway                  0.3440              0.3290          0.8734
# Finland                 0.3986              0.2178          0.8738
# Switzerland             0.3798              0.2776          0.9282
# Iceland                 0.1402              0.4192          0.9178
# Netherlands             0.2986              0.4150          0.8786
# Canada                  0.3058              0.3896          0.9008
# Sweden                  0.3974              0.3366          0.8990
# New Zealand             0.4000              0.4328          0.8916
# Australia               0.3144              0.4162          0.9146
#
#              Family Average  Economy GDP Average  Freedom Average  \
# Country
# Denmark              1.4478               1.3966           0.6258
# Norway               1.4312               1.5192           0.6380
# Finland              1.4344               1.3570           0.6216
# Switzerland          1.4174               1.4722           0.6208
# Iceland              1.4928               1.3866           0.6180
# Netherlands          1.3496               1.4110           0.5896
# Canada               1.3874               1.3880           0.6110
# Sweden               1.3686               1.4040           0.6176
# New Zealand          1.4398               1.3176           0.6176
# Australia            1.4090               1.3948           0.6050
#
#              Happiness Average
# Country
# Denmark                 7.5460
# Norway                  7.5410
# Finland                 7.5378
# Switzerland             7.5114
# Iceland                 7.5110
# Netherlands             7.4046
# Canada                  7.3506
# Sweden                  7.3192
# New Zealand             7.3130
# Australia               7.2762

# %%
# Export to CSV
Comparison_data.to_csv("Resources/Country_output.csv")

# %%
# Sort data in ascending order based on Average
# It is possible to sort based upon multiple columns
Comp_data_df = Comparison_data.sort_values(
    ["Economy GDP Average", "Freedom Average"], ascending=False)
Comp_data_df.head(10)
# Out:
#                Gov Trust Average  Generocity Average  Health Average  \
# Country
# Qatar                     0.3558              0.2912          0.7686
# Luxembourg                0.3374              0.2458          0.9034
# Singapore                 0.4672              0.3032          1.0140
# Kuwait                    0.1822              0.1718          0.6952
# Norway                    0.3440              0.3290          0.8734
# Switzerland               0.3798              0.2776          0.9282
# Ireland                   0.2998              0.3884          0.8790
# United States             0.1410              0.3552          0.8216
# Saudi Arabia              0.2314              0.1236          0.6662
# Netherlands               0.2986              0.4150          0.8786
#
#                Family Average  Economy GDP Average  Freedom Average  \
# Country
# Qatar                  1.1698               1.7436           0.6040
# Luxembourg             1.3434               1.6378           0.5840
# Singapore              1.2312               1.5922           0.5536
# Kuwait                 1.1848               1.5556           0.5060
# Norway                 1.4312               1.5192           0.6380
# Switzerland            1.4174               1.4722           0.6208
# Ireland                1.4450               1.4604           0.5722
# United States          1.3286               1.4560           0.5070
# Saudi Arabia           1.1814               1.4396           0.4174
# Netherlands            1.3496               1.4110           0.5896
#
#                Happiness Average
# Country
# Qatar                     6.4218
# Luxembourg                6.9360
# Singapore                 6.5428
# Kuwait                    6.1486
# Norway                    7.5410
# Switzerland               7.5114
# Ireland                   6.9644
# United States             6.9988
# Saudi Arabia              6.3760
# Netherlands               7.4046

# %% [markdown]
# ## ANOVA
#
# * Analysis of variance, or ANOVA, is a statistical method that separates observed variance data into different components to use for additional tests. A one-way ANOVA is used for three or more groups of data, to gain information about the relationship between the dependent and independent variables.

# %%
# Perform the ANOVA
st.f_oneway(Comp_data_df["Gov Trust Average"], 
            Comp_data_df["Generocity Average"], 
            Comp_data_df["Health Average"], 
            Comp_data_df["Family Average"], 
            Comp_data_df["Economy GDP Average"], 
            Comp_data_df["Freedom Average"])
# Out:
# F_onewayResult(statistic=394.32714337574123, pvalue=7.526071762437509e-217)

# %% [markdown]
# ## Correlation

# %%
# The next example will compute the Pearson correlation coefficient between "IEconomic GDP Average" and "Freedom Average"
GDP = Comp_data_df.iloc[:,4]
Free = Comp_data_df.iloc[:,5]
correlation = st.pearsonr(GDP,Free)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.39

# %%
# Compare the calcualted Pearson's r to the plots
plt.scatter(GDP,Free)
plt.xlabel('Country GDP Per Capita')
plt.ylabel('Average Freedom Score Per Country Per Year (L)')
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.39

# %%
# Generate the correlation matrix and find the strongest positive and negative correlations
all_data = Comp_data_df.corr()
all_data.unstack().sort_values()
# Out:
# Economy GDP Average  Generocity Average    -0.025530
# Generocity Average   Economy GDP Average   -0.025530
# Health Average       Generocity Average     0.032844
# Generocity Average   Health Average         0.032844
#                      Family Average         0.069850
# Family Average       Generocity Average     0.069850
# Generocity Average   Happiness Average      0.150190
# Happiness Average    Generocity Average     0.150190
# Gov Trust Average    Family Average         0.259132
# Family Average       Gov Trust Average      0.259132
# Generocity Average   Gov Trust Average      0.307336
# Gov Trust Average    Generocity Average     0.307336
# Health Average       Gov Trust Average      0.319317
# Gov Trust Average    Health Average         0.319317
# Generocity Average   Freedom Average        0.343940
# Freedom Average      Generocity Average     0.343940
#                      Health Average         0.370710
# Health Average       Freedom Average        0.370710
# Gov Trust Average    Economy GDP Average    0.375456
# Economy GDP Average  Gov Trust Average      0.375456
# Freedom Average      Economy GDP Average    0.390637
# Economy GDP Average  Freedom Average        0.390637
# Happiness Average    Gov Trust Average      0.451979
# Gov Trust Average    Happiness Average      0.451979
# Family Average       Freedom Average        0.487547
# Freedom Average      Family Average         0.487547
# Gov Trust Average    Freedom Average        0.509484
# Freedom Average      Gov Trust Average      0.509484
# Happiness Average    Freedom Average        0.583155
# Freedom Average      Happiness Average      0.583155
# Family Average       Health Average         0.641513
# Health Average       Family Average         0.641513
# Family Average       Economy GDP Average    0.700215
# Economy GDP Average  Family Average         0.700215
# Family Average       Happiness Average      0.785501
# Happiness Average    Family Average         0.785501
#                      Health Average         0.792512
# Health Average       Happiness Average      0.792512
# Happiness Average    Economy GDP Average    0.817523
# Economy GDP Average  Happiness Average      0.817523
#                      Health Average         0.847967
# Health Average       Economy GDP Average    0.847967
# Gov Trust Average    Gov Trust Average      1.000000
# Family Average       Family Average         1.000000
# Economy GDP Average  Economy GDP Average    1.000000
# Health Average       Health Average         1.000000
# Generocity Average   Generocity Average     1.000000
# Freedom Average      Freedom Average        1.000000
# Happiness Average    Happiness Average      1.000000
# dtype: float64

# %%
print (all_data.head())
sns.heatmap(all_data.corr(),annot=True, cmap='ocean')

plt.savefig('Images/Correlation_heatmap.png', dpi=300,bbox_inches='tight')
# Out:
#                      Gov Trust Average  Generocity Average  Health Average  \
# Gov Trust Average             1.000000            0.307336        0.319317
# Generocity Average            0.307336            1.000000        0.032844
# Health Average                0.319317            0.032844        1.000000
# Family Average                0.259132            0.069850        0.641513
# Economy GDP Average           0.375456           -0.025530        0.847967
#
#                      Family Average  Economy GDP Average  Freedom Average  \
# Gov Trust Average          0.259132             0.375456         0.509484
# Generocity Average         0.069850            -0.025530         0.343940
# Health Average             0.641513             0.847967         0.370710
# Family Average             1.000000             0.700215         0.487547
# Economy GDP Average        0.700215             1.000000         0.390637
#
#                      Happiness Average
# Gov Trust Average             0.451979
# Generocity Average            0.150190
# Health Average                0.792512
# Family Average                0.785501
# Economy GDP Average           0.817523

# %% [markdown]
# ## Linear Regression - Top Ten Countries

# %% [markdown]
# ### Trust (Government Corruption)

# %%
# Linear regression X and Y axis
x_values = top_ten_Comparison_data["Gov Trust Average"]
y_values = top_ten_Comparison_data["Happiness Average"]

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

correlation = st.pearsonr(x_values, y_values)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Trust (Government Corruption)")
plt.ylabel("Happiness Score")
plt.title(f'Average Happiness Score by Govenment Trust')
#plt.annotate(line_eq,(5,10),fontsize=15,color="r")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save and Show plot
plt.savefig("Images/Linear_Regression_GOVTrust.png")
plt.show()
# Out:
# y = -0.02x + 7.44
# The r-value is: 0.00031983404351783486

# %% [markdown]
# ### Generocity

# %%
# Linear regression X and Y axis
x_values = top_ten_Comparison_data["Generocity Average"]
y_values = top_ten_Comparison_data["Happiness Average"]

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

correlation = st.pearsonr(x_values, y_values)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Generocity")
plt.ylabel("Happiness Score")
plt.title(f'Average Happiness Score by Generocity')
#plt.annotate(line_eq,(5,10),fontsize=15,color="r")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save and Show plot
plt.savefig("Images/Linear_Regression_Generocity.png")
plt.show()
# Out:
# y = -0.95x + 7.77
# The r-value is: 0.3891533029316565

# %% [markdown]
# ### Health (Life Expectancy)

# %%
# Linear regression X and Y axis
x_values = top_ten_Comparison_data["Health Average"]
y_values = top_ten_Comparison_data["Happiness Average"]

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

correlation = st.pearsonr(x_values, y_values)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Health (Life Expectancy)")
plt.ylabel("Happiness Score")
plt.title(f'Average Happiness Score by Health (Life Expectancy)')
#plt.annotate(line_eq,(5,10),fontsize=15,color="r")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save and Show plot
plt.savefig("Images/Linear_Regression_Health.png")
plt.show()
# Out:
# y = -1.62x + 8.88
# The r-value is: 0.10050001600594213

# %% [markdown]
# ### Family

# %%
# Linear regression X and Y axis
x_values = top_ten_Comparison_data["Family Average"]
y_values = top_ten_Comparison_data["Happiness Average"]

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

correlation = st.pearsonr(x_values, y_values)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Family")
plt.ylabel("Happiness Score")
plt.title(f'Average Happiness Score by Family')
#plt.annotate(line_eq,(5,10),fontsize=15,color="r")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save and Show plot
plt.savefig("Images/Linear_Regression_Family.png")
plt.show()
# Out:
# y = 1.36x + 5.5
# The r-value is: 0.26936631068187095

# %% [markdown]
# ### Freedom

# %%
# Linear regression X and Y axis
x_values = top_ten_Comparison_data["Freedom Average"]
y_values = top_ten_Comparison_data["Happiness Average"]

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

correlation = st.pearsonr(x_values, y_values)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Freedom")
plt.ylabel("Happiness Score")
plt.title(f'Average Happiness Score by Freedom')
#plt.annotate(line_eq,(5,10),fontsize=15,color="r")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save and Show plot
plt.savefig("Images/Linear_Regression_Freedom.png")
plt.show()
# Out:
# y = 4.8x + 4.47
# The r-value is: 0.3192480402098517

# %% [markdown]
# ### Economy (GDP per Capita)

# %%
# Linear regression X and Y axis
x_values = top_ten_Comparison_data["Economy GDP Average"]
y_values = top_ten_Comparison_data["Happiness Average"]

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

correlation = st.pearsonr(x_values, y_values)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")
plt.title(f'Average Happiness Score by Economy (GDP per Capita)')
#plt.annotate(line_eq,(5,10),fontsize=15,color="r")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Save and Show plot
plt.savefig("Images/Linear_Regression_EconomyGDP.png")
plt.show()
# Out:
# y = 0.83x + 6.26
# The r-value is: 0.18363932424794105

# %%
# Economy (GDP per Capita) all Countries

# Linear regression X and Y axis
x_values = Comp_data_df["Economy GDP Average"]
y_values = Comp_data_df["Happiness Average"]

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

correlation = st.pearsonr(x_values, y_values)

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")
plt.title(f'Average Happiness Score by Economy (GDP per Capita)')
#plt.annotate(line_eq,(5,10),fontsize=15,color="r")

# Print r value
print(f"The r-value is: {rvalue**2}")
print(f"The p-value is: {pvalue}")

# Save and Show plot
plt.savefig("Images/Linear_Regression_EconomyGDP_All.png")
plt.show()
# Out:
# y = 2.33x + 3.26
# The r-value is: 0.6683439315322117
# The p-value is: 6.992878703184945e-35

# %%
# ?st.linregress

# %% [markdown]
# ## Region

# %%
# Summary of Happiness per year
Happiness_df = data[["Country", "Region", "Happiness Score 2015", "Happiness Score 2016", "Happiness Score 2017", "Happiness Score 2018", "Happiness Score 2019"]]
Happiness_df = Happiness_df.groupby("Region")
Happiness_df.mean()

#Find the averages of the data
Happ_df = Happiness_df.mean().reset_index()
Happ_df["Happiness Average"] = Happ_df.mean(axis=1)
Happ_df

# Filter the DataFrame down only to those columns to chart
Happiness_plot = Happ_df[["Region", "Happiness Average"]]

# Set the index to be "Region" so they will be used as labels
Happiness_plot = Happiness_plot.set_index("Region")
Happiness_plot.head(10)
# Out:
#                                  Happiness Average
# Region
# Australia and New Zealand                 7.294600
# Central and Eastern Europe                5.437643
# Eastern Asia                              5.514850
# Latin America and Caribbean               6.003100
# Middle East and Northern Africa           5.242200
# North America                             7.174700
# Southeastern Asia                         5.389475
# Southern Asia                             4.580657
# Sub-Saharan Africa                        4.190935
# Western Europe                            6.789330

# %%
dp=Happiness_plot.reset_index()
dp.sort_values(by=['Happiness Average'], inplace=True, ascending=False)
dp
# Out:
#                             Region  Happiness Average
# 0        Australia and New Zealand           7.294600
# 5                    North America           7.174700
# 9                   Western Europe           6.789330
# 3      Latin America and Caribbean           6.003100
# 2                     Eastern Asia           5.514850
# 1       Central and Eastern Europe           5.437643
# 6                Southeastern Asia           5.389475
# 4  Middle East and Northern Africa           5.242200
# 7                    Southern Asia           4.580657
# 8               Sub-Saharan Africa           4.190935

# %%
labels = dp["Region"]
values = dp["Happiness Average"]

# Change the bar colors here
plt.bar(labels, values, color=['green', 'blue', 'red', 'magenta', 'purple', 'yellow', 'orange','grey','black','brown'])

plt.xticks(rotation=90)

plt.ylim(4, 7.5)

plt.title("Average Happiness Score Per Region")
plt.ylabel('Happiness Score (Avg)')
plt.xlabel('Region')

# Save and Show plot
plt.savefig("Images/AverageHappiness_Region.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Geopandas World Map
#
# * Geopandas provides a high-level interface to the matplotlib library for making maps. Mapping shapes is as easy as using the plot() method on a GeoSeries or GeoDataFrame.

# %%
import geopandas as gpd
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# View first 5 rows of the World shape file data
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
# Inspect count of the World shape file data
world.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pop_est     177 non-null    int64
#  1   continent   177 non-null    object
#  2   name        177 non-null    object
#  3   iso_a3      177 non-null    object
#  4   gdp_md_est  177 non-null    float64
#  5   geometry    177 non-null    geometry
# dtypes: float64(1), geometry(1), int64(1), object(3)
# memory usage: 8.4+ KB

# %%
# Merge data sets

# merge both data sets using name/Country as unique identifiers
for_plotting = world.merge(Comp_data_df, left_on = 'name', right_on = 'Country')

# check the occurrence
for_plotting.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 128 entries, 0 to 127
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pop_est              128 non-null    int64
#  1   continent            128 non-null    object
#  2   name                 128 non-null    object
#  3   iso_a3               128 non-null    object
#  4   gdp_md_est           128 non-null    float64
#  5   geometry             128 non-null    geometry
#  6   Gov Trust Average    128 non-null    float64
#  7   Generocity Average   128 non-null    float64
#  8   Health Average       128 non-null    float64
#  9   Family Average       128 non-null    float64
#  10  Economy GDP Average  128 non-null    float64
#  11  Freedom Average      128 non-null    float64
#  12  Happiness Average    128 non-null    float64
# dtypes: float64(8), geometry(1), int64(1), object(3)
# memory usage: 14.0+ KB

# %%
#plot merged file.

ax = for_plotting.plot(column='Happiness Average', cmap = 'YlGnBu', figsize=(15,10), k=3, legend = True, 
                                legend_kwds={'label': "Happiness Score Per Country",'orientation':"horizontal"},
                                missing_kwds={'color': 'lightgrey'})
                                
ax.set_title('World Happiness Report \n 2015 - 2019', fontdict= {'fontsize':14})

plt.savefig("Images/WHR_ChoroplethMap.png")
