# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st

# %%
# Show path to csv files
original_data = "Resources/completData.csv"

# Read csv files through Pandas
data = pd.read_csv(original_data)

# %%
data.head(200)
# Out:
#          Country                           Region  Happiness Rank 2015  \
# 0    Switzerland                   Western Europe                  1.0
# 1        Iceland                   Western Europe                  2.0
# 2        Denmark                   Western Europe                  3.0
# 3         Norway                   Western Europe                  4.0
# 4         Canada                    North America                  5.0
# ..           ...                              ...                  ...
# 135       Rwanda               Sub-Saharan Africa                154.0
# 136        Benin               Sub-Saharan Africa                155.0
# 137        Syria  Middle East and Northern Africa                156.0
# 138      Burundi               Sub-Saharan Africa                157.0
# 139         Togo               Sub-Saharan Africa                158.0
#
#      Happiness Score 2015  Economy (GDP per Capita) 2015  Family 2015  \
# 0                   7.587                          1.397        1.350
# 1                   7.561                          1.302        1.402
# 2                   7.527                          1.325        1.361
# 3                   7.522                          1.459        1.331
# 4                   7.427                          1.326        1.323
# ..                    ...                            ...          ...
# 135                 3.465                          0.222        0.774
# 136                 3.340                          0.287        0.354
# 137                 3.006                          0.663        0.475
# 138                 2.905                          0.015        0.416
# 139                 2.839                          0.209        0.140
#
#      Health (Life Expectancy) 2015  Freedom 2015  \
# 0                            0.941         0.666
# 1                            0.948         0.629
# 2                            0.875         0.649
# 3                            0.885         0.670
# 4                            0.906         0.633
# ..                             ...           ...
# 135                          0.429         0.592
# 136                          0.319         0.485
# 137                          0.722         0.157
# 138                          0.224         0.119
# 139                          0.284         0.365
#
#      Trust (Government Corruption) 2015  Generosity 2015  ...  \
# 0                                 0.420            0.297  ...
# 1                                 0.141            0.436  ...
# 2                                 0.484            0.341  ...
# 3                                 0.365            0.347  ...
# 4                                 0.330            0.458  ...
# ..                                  ...              ...  ...
# 135                               0.552            0.226  ...
# 136                               0.080            0.183  ...
# 137                               0.189            0.472  ...
# 138                               0.101            0.197  ...
# 139                               0.107            0.167  ...
#
#      Trust (Government Corruption) 2018  Generosity 2018  Happiness Rank 2019  \
# 0                                 0.357            0.256                  6.0
# 1                                 0.138            0.353                  4.0
# 2                                 0.408            0.284                  2.0
# 3                                 0.340            0.286                  3.0
# 4                                 0.291            0.321                  9.0
# ..                                  ...              ...                  ...
# 135                               0.444            0.200                152.0
# 136                               0.067            0.163                102.0
# 137                               0.144            0.376                149.0
# 138                               0.076            0.149                145.0
# 139                               0.101            0.158                139.0
#
#      Happiness Score 2019  Economy (GDP per Capita) 2019  Family 2019  \
# 0                   7.480                          1.452        1.526
# 1                   7.494                          1.380        1.624
# 2                   7.600                          1.383        1.573
# 3                   7.554                          1.488        1.582
# 4                   7.278                          1.365        1.505
# ..                    ...                            ...          ...
# 135                 3.334                          0.359        0.711
# 136                 4.883                          0.393        0.437
# 137                 3.462                          0.619        0.378
# 138                 3.775                          0.046        0.447
# 139                 4.085                          0.275        0.572
#
#      Health (Life Expectancy) 2019  Freedom 2019  \
# 0                            1.052         0.572
# 1                            1.026         0.591
# 2                            0.996         0.592
# 3                            1.028         0.603
# 4                            1.039         0.584
# ..                             ...           ...
# 135                          0.614         0.555
# 136                          0.397         0.349
# 137                          0.440         0.013
# 138                          0.380         0.220
# 139                          0.410         0.293
#
#      Trust (Government Corruption) 2019  Generosity 2019
# 0                                 0.343            0.263
# 1                                 0.118            0.354
# 2                                 0.410            0.252
# 3                                 0.341            0.271
# 4                                 0.308            0.285
# ..                                  ...              ...
# 135                               0.411            0.217
# 136                               0.082            0.175
# 137                               0.141            0.331
# 138                               0.180            0.176
# 139                               0.085            0.177
#
# [140 rows x 42 columns]

# %%
# Create a group based on the values in the 'region' column
region_group = data.groupby('Region')

# Count how many times each region appears in our group
count_regions = region_group['Region'].count()

count_regions
# Out:
# Region
# Australia and New Zealand           2
# Central and Eastern Europe         28
# Eastern Asia                        4
# Latin America and Caribbean        20
# Middle East and Northern Africa    18
# North America                       2
# Southeastern Asia                   8
# Southern Asia                       7
# Sub-Saharan Africa                 31
# Western Europe                     20
# Name: Region, dtype: int64

# %%
# Create a bar chart based off of the Regions
count_chart = count_regions.plot(kind='bar', title="Region Bias")

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("Regions")
count_chart.set_ylabel("Number of Countries in Region")


plt.show()
plt.tight_layout()

# %%
# Group data with Region as index
complet_data_Summary = data.groupby("Region")
complet_data_Summary.mean()
# Out:
#                                  Happiness Rank 2015  Happiness Score 2015  \
# Region
# Australia and New Zealand                   9.500000              7.285000
# Central and Eastern Europe                 78.500000              5.344571
# Eastern Asia                               69.250000              5.496250
# Latin America and Caribbean                47.550000              6.137300
# Middle East and Northern Africa            83.888889              5.243556
# North America                              10.000000              7.273000
# Southeastern Asia                          79.000000              5.372625
# Southern Asia                             113.142857              4.580857
# Sub-Saharan Africa                        131.096774              4.120419
# Western Europe                             27.700000              6.739350
#
#                                  Economy (GDP per Capita) 2015  Family 2015  \
# Region
# Australia and New Zealand                             1.292000     1.314500
# Central and Eastern Europe                            0.943250     1.054821
# Eastern Asia                                          1.058500     1.115750
# Latin America and Caribbean                           0.854200     1.107450
# Middle East and Northern Africa                       1.030611     0.900167
# North America                                         1.360500     1.285000
# Southeastern Asia                                     0.813750     0.965625
# Southern Asia                                         0.560429     0.645286
# Sub-Saharan Africa                                    0.381387     0.806935
# Western Europe                                        1.303050     1.256100
#
#                                  Health (Life Expectancy) 2015  Freedom 2015  \
# Region
# Australia and New Zealand                             0.920000      0.645000
# Central and Eastern Europe                            0.718107      0.359071
# Eastern Asia                                          0.844000      0.445250
# Latin America and Caribbean                           0.713050      0.494150
# Middle East and Northern Africa                       0.696667      0.331167
# North America                                         0.884000      0.589500
# Southeastern Asia                                     0.693375      0.552125
# Southern Asia                                         0.540857      0.373286
# Sub-Saharan Africa                                    0.299484      0.381484
# Western Europe                                        0.908400      0.553050
#
#                                  Trust (Government Corruption) 2015  \
# Region
# Australia and New Zealand                                  0.392500
# Central and Eastern Europe                                 0.087821
# Eastern Asia                                               0.078750
# Latin America and Caribbean                                0.121550
# Middle East and Northern Africa                            0.162389
# North America                                              0.244500
# Southeastern Asia                                          0.139750
# Southern Asia                                              0.102571
# Sub-Saharan Africa                                         0.111710
# Western Europe                                             0.235850
#
#                                  Generosity 2015  Happiness Rank 2016  \
# Region
# Australia and New Zealand               0.455500             8.500000
# Central and Eastern Europe              0.149643            77.857143
# Eastern Asia                            0.176750            73.500000
# Latin America and Caribbean             0.215100            50.500000
# Middle East and Northern Africa         0.185000            80.888889
# North America                           0.429500             9.500000
# Southeastern Asia                       0.419000            77.250000
# Southern Asia                           0.341429           111.714286
# Sub-Saharan Africa                      0.221452           131.806452
# Western Europe                          0.304100            27.550000
#
#                                  Happiness Score 2016  ...  \
# Region                                                 ...
# Australia and New Zealand                    7.323500  ...
# Central and Eastern Europe                   5.379607  ...
# Eastern Asia                                 5.477000  ...
# Latin America and Caribbean                  6.050500  ...
# Middle East and Northern Africa              5.320111  ...
# North America                                7.254000  ...
# Southeastern Asia                            5.396750  ...
# Southern Asia                                4.563286  ...
# Sub-Saharan Africa                           4.074839  ...
# Western Europe                               6.731400  ...
#
#                                  Trust (Government Corruption) 2018  \
# Region
# Australia and New Zealand                                  0.345500
# Central and Eastern Europe                                 0.062643
# Eastern Asia                                               0.084000
# Latin America and Caribbean                                0.079300
# Middle East and Northern Africa                            0.122944
# North America                                              0.212000
# Southeastern Asia                                          0.123750
# Southern Asia                                              0.097857
# Sub-Saharan Africa                                         0.085097
# Western Europe                                             0.214150
#
#                                  Generosity 2018  Happiness Rank 2019  \
# Region
# Australia and New Zealand               0.363000             9.500000
# Central and Eastern Europe              0.131571            70.500000
# Eastern Asia                            0.134000            72.000000
# Latin America and Caribbean             0.137850            52.000000
# Middle East and Northern Africa         0.159556            88.444444
# North America                           0.306000            14.000000
# Southeastern Asia                       0.321375            82.625000
# Southern Asia                           0.243571           115.857143
# Sub-Saharan Africa                      0.177806           122.322581
# Western Europe                          0.223850            21.350000
#
#                                  Happiness Score 2019  \
# Region
# Australia and New Zealand                    7.267500
# Central and Eastern Europe                   5.571786
# Eastern Asia                                 5.564250
# Latin America and Caribbean                  5.942550
# Middle East and Northern Africa              5.148778
# North America                                7.085000
# Southeastern Asia                            5.333375
# Southern Asia                                4.526857
# Sub-Saharan Africa                           4.380323
# Western Europe                               6.898400
#
#                                  Economy (GDP per Capita) 2019  Family 2019  \
# Region
# Australia and New Zealand                             1.337500     1.552500
# Central and Eastern Europe                            1.022429     1.340393
# Eastern Asia                                          1.151250     1.323500
# Latin America and Caribbean                           0.908950     1.332850
# Middle East and Northern Africa                       1.034389     1.139722
# North America                                         1.399000     1.481000
# Southeastern Asia                                     0.950750     1.273500
# Southern Asia                                         0.650286     0.986857
# Sub-Saharan Africa                                    0.466226     0.938097
# Western Europe                                        1.362050     1.483900
#
#                                  Health (Life Expectancy) 2019  Freedom 2019  \
# Region
# Australia and New Zealand                             1.031000      0.571000
# Central and Eastern Europe                            0.808500      0.357964
# Eastern Asia                                          0.921000      0.360500
# Latin America and Caribbean                           0.816800      0.438500
# Middle East and Northern Africa                       0.746944      0.302389
# North America                                         0.956500      0.519000
# Southeastern Asia                                     0.769625      0.543375
# Southern Asia                                         0.617000      0.386286
# Sub-Saharan Africa                                    0.440839      0.342226
# Western Europe                                        1.013850      0.482550
#
#                                  Trust (Government Corruption) 2019  \
# Region
# Australia and New Zealand                                  0.335000
# Central and Eastern Europe                                 0.062750
# Eastern Asia                                               0.083500
# Latin America and Caribbean                                0.074850
# Middle East and Northern Africa                            0.100722
# North America                                              0.218000
# Southeastern Asia                                          0.118375
# Southern Asia                                              0.093429
# Sub-Saharan Africa                                         0.087645
# Western Europe                                             0.221200
#
#                                  Generosity 2019
# Region
# Australia and New Zealand               0.331000
# Central and Eastern Europe              0.141214
# Eastern Asia                            0.134250
# Latin America and Caribbean             0.142600
# Middle East and Northern Africa         0.147444
# North America                           0.282500
# Southeastern Asia                       0.306250
# Southern Asia                           0.234714
# Sub-Saharan Africa                      0.188290
# Western Europe                          0.221050
#
# [10 rows x 40 columns]

# %%
list(data.columns)
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank 2015',
#  'Happiness Score 2015',
#  'Economy (GDP per Capita) 2015',
#  'Family 2015',
#  'Health (Life Expectancy) 2015',
#  'Freedom 2015',
#  'Trust (Government Corruption) 2015',
#  'Generosity 2015',
#  'Happiness Rank 2016',
#  'Happiness Score 2016',
#  'Economy (GDP per Capita) 2016',
#  'Family 2016',
#  'Health (Life Expectancy) 2016',
#  'Freedom 2016',
#  'Trust (Government Corruption) 2016',
#  'Generosity 2016',
#  'Happiness Rank 2017',
#  'Happiness Score 2017',
#  'Economy (GDP per Capita) 2017',
#  'Family 2017',
#  'Health (Life Expectancy) 2017',
#  'Freedom 2017',
#  'Trust (Government Corruption) 2017',
#  'Generosity 2017',
#  'Happiness Rank 2018',
#  'Happiness Score 2018',
#  'Economy (GDP per Capita) 2018',
#  'Family 2018',
#  'Health (Life Expectancy) 2018',
#  'Freedom 2018',
#  'Trust (Government Corruption) 2018',
#  'Generosity 2018',
#  'Happiness Rank 2019',
#  'Happiness Score 2019',
#  'Economy (GDP per Capita) 2019',
#  'Family 2019',
#  'Health (Life Expectancy) 2019',
#  'Freedom 2019',
#  'Trust (Government Corruption) 2019',
#  'Generosity 2019']

# %%
# Summary of Generocity per year
Trust_df = data[["Country", "Region", "Trust (Government Corruption) 2015", "Trust (Government Corruption) 2016", "Trust (Government Corruption) 2017", "Trust (Government Corruption) 2018", "Trust (Government Corruption) 2019"]]
Trust_df = Trust_df.groupby("Region")
Trust_df.mean()

#Find the averages of the data
GOV_df = Trust_df.mean().reset_index()
GOV_df["Gov Trust Average"] = GOV_df.mean(axis=1)
GOV_df

# Filter the DataFrame down only to those columns to chart
GOV_plot = GOV_df[["Region", "Gov Trust Average"]]

# Set the index to be "Region" so they will be used as labels
GOV_plot = GOV_plot.set_index("Region")
GOV_plot.head()
# Out:
#                                  Gov Trust Average
# Region
# Australia and New Zealand                 0.357200
# Central and Eastern Europe                0.076421
# Eastern Asia                              0.079750
# Latin America and Caribbean               0.095130
# Middle East and Northern Africa           0.135222

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
GOV_plot.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Government Trust Score Per Region")

plt.show()
plt.tight_layout()

# %%
# Summary of Generocity per year
Generocity_df = data[["Country", "Region", "Generosity 2015", "Generosity 2016", "Generosity 2017", "Generosity 2018", "Generosity 2019"]]
Generocity_df = Generocity_df.groupby("Region")
Generocity_df.mean()

#Find the averages of the data
Gen_df = Generocity_df.mean().reset_index()
Gen_df["Generocity Average"] = Gen_df.mean(axis=1)
Gen_df

# Filter the DataFrame down only to those columns to chart
Gen_plot = Gen_df[["Region", "Generocity Average"]]

# Set the index to be "Region" so they will be used as labels
Gen_plot = Gen_plot.set_index("Region")
Gen_plot.head()
# Out:
#                                  Generocity Average
# Region
# Australia and New Zealand                  0.424500
# Central and Eastern Europe                 0.154914
# Eastern Asia                               0.158000
# Latin America and Caribbean                0.180400
# Middle East and Northern Africa            0.172911

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Gen_plot.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Generocity Score Per Region")

plt.show()
plt.tight_layout()

# %%
# Summary of Health per year
Health_df = data[["Country", "Region", "Health (Life Expectancy) 2015","Health (Life Expectancy) 2016", "Health (Life Expectancy) 2017", "Health (Life Expectancy) 2018", "Health (Life Expectancy) 2019"]]
Health_df = Health_df.groupby("Region")
Health_df.mean()

#Find the averages of the data
Heal_df = Health_df.mean().reset_index()
Heal_df["Health Average"] = Heal_df.mean(axis=1)
Heal_df

# Filter the DataFrame down only to those columns to chart
Health_plot = Heal_df[["Region", "Health Average"]]

# Set the index to be "Region" so they will be used as labels
Health_plot = Health_plot.set_index("Region")
Health_plot.head()
# Out:
#                                  Health Average
# Region
# Australia and New Zealand              0.903100
# Central and Eastern Europe             0.695986
# Eastern Asia                           0.829050
# Latin America and Caribbean            0.688300
# Middle East and Northern Africa        0.659667

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Health_plot.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Life Expectancy Per Region")

plt.show()
plt.tight_layout()

# %%
# Summary of Family per year
Family_df = data[["Country", "Region", "Family 2015", "Family 2016", "Family 2017", "Family 2018", "Family 2019"]]
Family_df = Family_df.groupby("Region")
Family_df.mean()

#Find the averages of the data
Fam_df = Family_df.mean().reset_index()
Fam_df["Family Average"] = Fam_df.mean(axis=1)
Fam_df

# Filter the DataFrame down only to those columns to chart
Family_plot = Fam_df[["Region", "Family Average"]]

# Set the index to be "Region" so they will be used as labels
Family_plot = Family_plot.set_index("Region")
Family_plot.head()
# Out:
#                                  Family Average
# Region
# Australia and New Zealand              1.424400
# Central and Eastern Europe             1.174757
# Eastern Asia                           1.198350
# Latin America and Caribbean            1.195410
# Middle East and Northern Africa        0.988267

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Family_plot.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average GDP Per Region")

plt.show()
plt.tight_layout()

# %%
#Summary of Freedom score
Freedom_df = data[["Country", "Region", "Freedom 2015", "Freedom 2016", "Freedom 2017", "Freedom 2018", "Freedom 2019"]]
Freedom_df = Freedom_df.groupby("Region")
Freedom_df.mean()

#Find the averages of the data
Free_df = Freedom_df.mean().reset_index()
Free_df["Freedom Average"] = Free_df.mean(axis=1)
Free_df

#sort data in ascending order based on Average
Free_df.sort_values(by=['Freedom Average'], inplace=True, ascending=False)
Free_df

# Filter the DataFrame down only to those columns to chart
Freedom_plot = Free_df[["Region", "Freedom Average"]]

# Set the index to be "Region" so they will be used as labels
Freedom_plot = Freedom_plot.set_index("Region")
Freedom_plot.head()
# Out:
#                              Freedom Average
# Region
# Australia and New Zealand            0.61130
# North America                        0.55900
# Southeastern Asia                    0.54080
# Western Europe                       0.51842
# Latin America and Caribbean          0.45675

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Freedom_plot.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Freedom Score Per Region")

plt.show()
plt.tight_layout()

# %%
# Summary of Happiness per year
Happiness_df = data[["Country", "Region", "Happiness Score 2015", "Happiness Score 2016", "Happiness Score 2017", "Happiness Score 2018", "Happiness Score 2019"]]
Happiness_df = Happiness_df.groupby("Region")
Happiness_df.mean()

#Find the averages of the data
Happ_df = Happiness_df.mean().reset_index()
Happ_df["Happiness Average"] = Happ_df.mean(axis=1)
Happ_df

# Filter the DataFrame down only to those columns to chart
Happiness_plot = Happ_df[["Region", "Happiness Average"]]

# Set the index to be "Region" so they will be used as labels
Happiness_plot = Happiness_plot.set_index("Region")
Happiness_plot.head()
# Out:
#                                  Happiness Average
# Region
# Australia and New Zealand                 7.294600
# Central and Eastern Europe                5.437643
# Eastern Asia                              5.514850
# Latin America and Caribbean               6.003100
# Middle East and Northern Africa           5.242200

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Happiness_plot.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average Happiness Score Per Region")

plt.show()
plt.tight_layout()

# %%
# Summary of Happiness per year
Economy_df = data[["Country", "Region", "Economy (GDP per Capita) 2015","Economy (GDP per Capita) 2016", "Economy (GDP per Capita) 2017", "Economy (GDP per Capita) 2018", "Economy (GDP per Capita) 2019" ]]
Economy_df = Economy_df.groupby("Region")
Economy_df.mean()

#Find the averages of the data
Econ_df = Happiness_df.mean().reset_index()
Econ_df["Economy GDP Average"] = Econ_df.mean(axis=1)
Econ_df

# Filter the DataFrame down only to those columns to chart
Economy_plot = Econ_df[["Region", "Economy GDP Average"]]

# Set the index to be "Region" so they will be used as labels
Economy_plot = Economy_plot.set_index("Region")
Economy_plot.head()
Economy_plot.head()
# Out:
#                                  Economy GDP Average
# Region
# Australia and New Zealand                   7.294600
# Central and Eastern Europe                  5.437643
# Eastern Asia                                5.514850
# Latin America and Caribbean                 6.003100
# Middle East and Northern Africa             5.242200

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
Economy_plot.plot(kind="bar", figsize=(5,3))

# Set a title for the chart
plt.title("Average GDP Per Region")

plt.show()
plt.tight_layout()

# %%
# Set x axis and tick locations
x_axis = np.arange(len(Economy_plot))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.bar(x_axis, Economy_plot["Economy GDP Average"], color='r', alpha=1, align="center")
plt.xticks(tick_locations, Economy_plot["Region"], rotation="vertical")
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-532589387b1a> in <module>
#       1 # Create a list indicating where to write x labels and set figure size to adjust for space
#       2 plt.bar(x_axis, Economy_plot["Economy GDP Average"], color='r', alpha=1, align="center")
# ----> 3 plt.xticks(tick_locations, Economy_plot["Region"], rotation="vertical")
#       4 plt.tight_layout()
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'

# %%
#Merge all average columns together 
# Merging Data on Region
Comparison_data = pd.merge(GOV_plot, Gen_plot, on = ["Region"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Health_plot, on = ["Region"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Family_plot, on = ["Region"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Economy_plot, on = ["Region"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Freedom_plot, on = ["Region"], how = "outer")
Comparison_data = pd.merge(Comparison_data, Happiness_plot, on = ["Region"], how = "outer")
Comparison_data
# Out:
#                                  Gov Trust Average  Generocity Average  \
# Region
# Australia and New Zealand                 0.357200            0.424500
# Central and Eastern Europe                0.076421            0.154914
# Eastern Asia                              0.079750            0.158000
# Latin America and Caribbean               0.095130            0.180400
# Middle East and Northern Africa           0.135222            0.172911
# North America                             0.223400            0.372400
# Southeastern Asia                         0.129625            0.388950
# Southern Asia                             0.100371            0.300886
# Sub-Saharan Africa                        0.096948            0.209477
# Western Europe                            0.225860            0.272250
#
#                                  Health Average  Family Average  \
# Region
# Australia and New Zealand              0.903100        1.424400
# Central and Eastern Europe             0.695986        1.174757
# Eastern Asia                           0.829050        1.198350
# Latin America and Caribbean            0.688300        1.195410
# Middle East and Northern Africa        0.659667        0.988267
# North America                          0.861200        1.358000
# Southeastern Asia                      0.650900        1.119225
# Southern Asia                          0.513086        0.803771
# Sub-Saharan Africa                     0.302039        0.857232
# Western Europe                         0.893450        1.348270
#
#                                  Economy GDP Average  Freedom Average  \
# Region
# Australia and New Zealand                   7.294600         0.611300
# Central and Eastern Europe                  5.437643         0.352814
# Eastern Asia                                5.514850         0.408150
# Latin America and Caribbean                 6.003100         0.456750
# Middle East and Northern Africa             5.242200         0.334967
# North America                               7.174700         0.559000
# Southeastern Asia                           5.389475         0.540800
# Southern Asia                               4.580657         0.392829
# Sub-Saharan Africa                          4.190935         0.366503
# Western Europe                              6.789330         0.518420
#
#                                  Happiness Average
# Region
# Australia and New Zealand                 7.294600
# Central and Eastern Europe                5.437643
# Eastern Asia                              5.514850
# Latin America and Caribbean               6.003100
# Middle East and Northern Africa           5.242200
# North America                             7.174700
# Southeastern Asia                         5.389475
# Southern Asia                             4.580657
# Sub-Saharan Africa                        4.190935
# Western Europe                            6.789330

# %%
# Using .rename(columns={}) in order to rename columns
renamed_df = Comparison_data.rename(columns={"Average":"Economic GDP Average"})
renamed_df
renamed_df.to_csv("Resources/Region_output.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-26-d39162219890> in <module>
#       2 renamed_df = Comparison_data.rename(columns={"Average":"Economic GDP Average"})
#       3 renamed_df
# ----> 4 renamed_df.to_csv("Resources/Region_output.csv")
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# c:\users\alysh\anaconda3\envs\pythondata\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'Resources/Region_output.csv'

# %%
#sort data in ascending order based on Average
# It is possible to sort based upon multiple columns
Comp_data_df = Comparison_data.sort_values(
    ["Economy GDP Average", "Freedom Average"], ascending=False)
Comp_data_df.head(10)

# %%
#  The index can be reset to provide index numbers based on the new rankings.
#new_index_df = Comp_data_df.reset_index(drop=True)
#Comp_data_df.head(10)

# %%
# Group our data based upon 'Region' and 'country'
Region_groups = data.groupby(['Region','Country'])
Region_groups.head()

# Create a new variable that holds the sum of our groups
sum_region = Region_groups.sum()
sum_region.head(200)

# %%
# Make a variable called region_id and store a 'region' in it
region_id = "Sub-Saharan Africa"

# Collect the countries of the 'region_id' above
country_id = sum_region.loc[region_id]

country_id
# Out:
#                      Happiness Rank 2015  Happiness Score 2015  \
# Country
# Benin                              155.0                 3.340
# Botswana                           128.0                 4.332
# Burkina Faso                       152.0                 3.587
# Burundi                            157.0                 2.905
# Cameroon                           133.0                 4.252
# Chad                               149.0                 3.667
# Congo (Brazzaville)                139.0                 3.989
# Congo (Kinshasa)                   120.0                 4.517
# Ethiopia                           122.0                 4.512
# Gabon                              143.0                 3.896
# Ghana                              114.0                 4.633
# Guinea                             150.0                 3.656
# Ivory Coast                        151.0                 3.655
# Kenya                              125.0                 4.419
# Liberia                            116.0                 4.571
# Madagascar                         147.0                 3.681
# Malawi                             131.0                 4.292
# Mali                               138.0                 3.995
# Mauritania                         124.0                 4.436
# Mauritius                           71.0                 5.477
# Niger                              144.0                 3.845
# Nigeria                             78.0                 5.268
# Rwanda                             154.0                 3.465
# Senegal                            142.0                 3.904
# Sierra Leone                       123.0                 4.507
# South Africa                       113.0                 4.642
# Tanzania                           146.0                 3.781
# Togo                               158.0                 2.839
# Uganda                             141.0                 3.931
# Zambia                              85.0                 5.129
# Zimbabwe                           115.0                 4.610
#
#                      Economy (GDP per Capita) 2015  Family 2015  \
# Country
# Benin                                        0.287        0.354
# Botswana                                     0.994        1.105
# Burkina Faso                                 0.258        0.852
# Burundi                                      0.015        0.416
# Cameroon                                     0.423        0.888
# Chad                                         0.342        0.761
# Congo (Brazzaville)                          0.679        0.663
# Congo (Kinshasa)                             0.000        1.001
# Ethiopia                                     0.191        0.604
# Gabon                                        1.060        0.905
# Ghana                                        0.546        0.680
# Guinea                                       0.174        0.465
# Ivory Coast                                  0.465        0.771
# Kenya                                        0.365        0.999
# Liberia                                      0.071        0.790
# Madagascar                                   0.208        0.668
# Malawi                                       0.016        0.411
# Mali                                         0.261        1.035
# Mauritania                                   0.454        0.869
# Mauritius                                    1.008        0.985
# Niger                                        0.069        0.773
# Nigeria                                      0.654        0.904
# Rwanda                                       0.222        0.774
# Senegal                                      0.365        0.976
# Sierra Leone                                 0.330        0.956
# South Africa                                 0.920        1.185
# Tanzania                                     0.285        1.003
# Togo                                         0.209        0.140
# Uganda                                       0.211        1.133
# Zambia                                       0.470        0.916
# Zimbabwe                                     0.271        1.033
#
#                      Health (Life Expectancy) 2015  Freedom 2015  \
# Country
# Benin                                        0.319         0.485
# Botswana                                     0.048         0.495
# Burkina Faso                                 0.271         0.395
# Burundi                                      0.224         0.119
# Cameroon                                     0.234         0.493
# Chad                                         0.150         0.235
# Congo (Brazzaville)                          0.311         0.415
# Congo (Kinshasa)                             0.098         0.226
# Ethiopia                                     0.441         0.435
# Gabon                                        0.434         0.319
# Ghana                                        0.401         0.423
# Guinea                                       0.240         0.377
# Ivory Coast                                  0.152         0.469
# Kenya                                        0.414         0.422
# Liberia                                      0.342         0.285
# Madagascar                                   0.467         0.192
# Malawi                                       0.226         0.431
# Mali                                         0.206         0.389
# Mauritania                                   0.359         0.242
# Mauritius                                    0.710         0.561
# Niger                                        0.297         0.477
# Nigeria                                      0.160         0.343
# Rwanda                                       0.429         0.592
# Senegal                                      0.435         0.368
# Sierra Leone                                 0.000         0.408
# South Africa                                 0.277         0.332
# Tanzania                                     0.382         0.329
# Togo                                         0.284         0.365
# Uganda                                       0.339         0.457
# Zambia                                       0.299         0.488
# Zimbabwe                                     0.335         0.259
#
#                      Trust (Government Corruption) 2015  Generosity 2015  \
# Country
# Benin                                             0.080            0.183
# Botswana                                          0.125            0.105
# Burkina Faso                                      0.128            0.217
# Burundi                                           0.101            0.197
# Cameroon                                          0.058            0.206
# Chad                                              0.053            0.184
# Congo (Brazzaville)                               0.117            0.124
# Congo (Kinshasa)                                  0.076            0.248
# Ethiopia                                          0.150            0.243
# Gabon                                             0.111            0.068
# Ghana                                             0.044            0.231
# Guinea                                            0.121            0.287
# Ivory Coast                                       0.179            0.202
# Kenya                                             0.058            0.375
# Liberia                                           0.062            0.244
# Madagascar                                        0.081            0.213
# Malawi                                            0.070            0.331
# Mali                                              0.124            0.188
# Mauritania                                        0.175            0.219
# Mauritius                                         0.075            0.377
# Niger                                             0.156            0.194
# Nigeria                                           0.040            0.272
# Rwanda                                            0.552            0.226
# Senegal                                           0.107            0.208
# Sierra Leone                                      0.088            0.215
# South Africa                                      0.089            0.120
# Tanzania                                          0.057            0.344
# Togo                                              0.107            0.167
# Uganda                                            0.073            0.291
# Zambia                                            0.125            0.196
# Zimbabwe                                          0.081            0.190
#
#                      Happiness Rank 2016  Happiness Score 2016  ...  \
# Country                                                         ...
# Benin                              153.0                 3.484  ...
# Botswana                           137.0                 3.974  ...
# Burkina Faso                       145.0                 3.739  ...
# Burundi                            157.0                 2.905  ...
# Cameroon                           114.0                 4.513  ...
# Chad                               144.0                 3.763  ...
# Congo (Brazzaville)                127.0                 4.236  ...
# Congo (Kinshasa)                   125.0                 4.272  ...
# Ethiopia                           115.0                 4.508  ...
# Gabon                              134.0                 4.121  ...
# Ghana                              124.0                 4.276  ...
# Guinea                             151.0                 3.607  ...
# Ivory Coast                        139.0                 3.916  ...
# Kenya                              122.0                 4.356  ...
# Liberia                            150.0                 3.622  ...
# Madagascar                         148.0                 3.695  ...
# Malawi                             132.0                 4.156  ...
# Mali                               135.0                 4.073  ...
# Mauritania                         130.0                 4.201  ...
# Mauritius                           66.0                 5.648  ...
# Niger                              142.0                 3.856  ...
# Nigeria                            103.0                 4.875  ...
# Rwanda                             152.0                 3.515  ...
# Senegal                            128.0                 4.219  ...
# Sierra Leone                       111.0                 4.635  ...
# South Africa                       116.0                 4.459  ...
# Tanzania                           149.0                 3.666  ...
# Togo                               155.0                 3.303  ...
# Uganda                             145.0                 3.739  ...
# Zambia                             106.0                 4.795  ...
# Zimbabwe                           131.0                 4.193  ...
#
#                      Trust (Government Corruption) 2018  Generosity 2018  \
# Country
# Benin                                             0.067            0.163
# Botswana                                          0.092            0.042
# Burkina Faso                                      0.128            0.175
# Burundi                                           0.076            0.149
# Cameroon                                          0.043            0.183
# Chad                                              0.060            0.181
# Congo (Brazzaville)                               0.077            0.091
# Congo (Kinshasa)                                  0.052            0.197
# Ethiopia                                          0.146            0.220
# Gabon                                             0.052            0.032
# Ghana                                             0.029            0.212
# Guinea                                            0.094            0.185
# Ivory Coast                                       0.103            0.146
# Kenya                                             0.055            0.352
# Liberia                                           0.030            0.206
# Madagascar                                        0.049            0.155
# Malawi                                            0.080            0.210
# Mali                                              0.056            0.139
# Mauritania                                        0.093            0.134
# Mauritius                                         0.050            0.245
# Niger                                             0.099            0.175
# Nigeria                                           0.032            0.201
# Rwanda                                            0.444            0.200
# Senegal                                           0.082            0.138
# Sierra Leone                                      0.053            0.238
# South Africa                                      0.056            0.103
# Tanzania                                          0.097            0.270
# Togo                                              0.101            0.158
# Uganda                                            0.061            0.259
# Zambia                                            0.082            0.221
# Zimbabwe                                          0.099            0.132
#
#                      Happiness Rank 2019  Happiness Score 2019  \
# Country
# Benin                              102.0                 4.883
# Botswana                           148.0                 3.488
# Burkina Faso                       115.0                 4.587
# Burundi                            145.0                 3.775
# Cameroon                            96.0                 5.044
# Chad                               132.0                 4.350
# Congo (Brazzaville)                103.0                 4.812
# Congo (Kinshasa)                   127.0                 4.418
# Ethiopia                           134.0                 4.286
# Gabon                              104.0                 4.799
# Ghana                               98.0                 4.996
# Guinea                             118.0                 4.534
# Ivory Coast                         99.0                 4.944
# Kenya                              121.0                 4.509
# Liberia                            141.0                 3.975
# Madagascar                         143.0                 3.933
# Malawi                             150.0                 3.410
# Mali                               128.0                 4.390
# Mauritania                         122.0                 4.490
# Mauritius                           57.0                 5.888
# Niger                              114.0                 4.628
# Nigeria                             85.0                 5.265
# Rwanda                             152.0                 3.334
# Senegal                            111.0                 4.681
# Sierra Leone                       129.0                 4.374
# South Africa                       106.0                 4.722
# Tanzania                           153.0                 3.231
# Togo                               139.0                 4.085
# Uganda                             136.0                 4.189
# Zambia                             138.0                 4.107
# Zimbabwe                           146.0                 3.663
#
#                      Economy (GDP per Capita) 2019  Family 2019  \
# Country
# Benin                                        0.393        0.437
# Botswana                                     1.041        1.145
# Burkina Faso                                 0.331        1.056
# Burundi                                      0.046        0.447
# Cameroon                                     0.549        0.910
# Chad                                         0.350        0.766
# Congo (Brazzaville)                          0.673        0.799
# Congo (Kinshasa)                             0.094        1.125
# Ethiopia                                     0.336        1.033
# Gabon                                        1.057        1.183
# Ghana                                        0.611        0.868
# Guinea                                       0.380        0.829
# Ivory Coast                                  0.569        0.808
# Kenya                                        0.512        0.983
# Liberia                                      0.073        0.922
# Madagascar                                   0.274        0.916
# Malawi                                       0.191        0.560
# Mali                                         0.385        1.105
# Mauritania                                   0.570        1.167
# Mauritius                                    1.120        1.402
# Niger                                        0.138        0.774
# Nigeria                                      0.696        1.111
# Rwanda                                       0.359        0.711
# Senegal                                      0.450        1.134
# Sierra Leone                                 0.268        0.841
# South Africa                                 0.960        1.351
# Tanzania                                     0.476        0.885
# Togo                                         0.275        0.572
# Uganda                                       0.332        1.069
# Zambia                                       0.578        1.058
# Zimbabwe                                     0.366        1.114
#
#                      Health (Life Expectancy) 2019  Freedom 2019  \
# Country
# Benin                                        0.397         0.349
# Botswana                                     0.538         0.455
# Burkina Faso                                 0.380         0.255
# Burundi                                      0.380         0.220
# Cameroon                                     0.331         0.381
# Chad                                         0.192         0.174
# Congo (Brazzaville)                          0.508         0.372
# Congo (Kinshasa)                             0.357         0.269
# Ethiopia                                     0.532         0.344
# Gabon                                        0.571         0.295
# Ghana                                        0.486         0.381
# Guinea                                       0.375         0.332
# Ivory Coast                                  0.232         0.352
# Kenya                                        0.581         0.431
# Liberia                                      0.443         0.370
# Madagascar                                   0.555         0.148
# Malawi                                       0.495         0.443
# Mali                                         0.308         0.327
# Mauritania                                   0.489         0.066
# Mauritius                                    0.798         0.498
# Niger                                        0.366         0.318
# Nigeria                                      0.245         0.426
# Rwanda                                       0.614         0.555
# Senegal                                      0.571         0.292
# Sierra Leone                                 0.242         0.309
# South Africa                                 0.469         0.389
# Tanzania                                     0.499         0.417
# Togo                                         0.410         0.293
# Uganda                                       0.443         0.356
# Zambia                                       0.426         0.431
# Zimbabwe                                     0.433         0.361
#
#                      Trust (Government Corruption) 2019  Generosity 2019
# Country
# Benin                                             0.082            0.175
# Botswana                                          0.100            0.025
# Burkina Faso                                      0.113            0.177
# Burundi                                           0.180            0.176
# Cameroon                                          0.037            0.187
# Chad                                              0.078            0.198
# Congo (Brazzaville)                               0.093            0.105
# Congo (Kinshasa)                                  0.053            0.212
# Ethiopia                                          0.100            0.209
# Gabon                                             0.055            0.043
# Ghana                                             0.040            0.245
# Guinea                                            0.086            0.207
# Ivory Coast                                       0.090            0.154
# Kenya                                             0.053            0.372
# Liberia                                           0.033            0.233
# Madagascar                                        0.041            0.169
# Malawi                                            0.089            0.218
# Mali                                              0.052            0.153
# Mauritania                                        0.088            0.106
# Mauritius                                         0.060            0.215
# Niger                                             0.102            0.188
# Nigeria                                           0.041            0.215
# Rwanda                                            0.411            0.217
# Senegal                                           0.072            0.153
# Sierra Leone                                      0.045            0.252
# South Africa                                      0.055            0.130
# Tanzania                                          0.147            0.276
# Togo                                              0.085            0.177
# Uganda                                            0.060            0.252
# Zambia                                            0.087            0.247
# Zimbabwe                                          0.089            0.151
#
# [31 rows x 40 columns]

# %%
# The next example will compute the Pearson correlation coefficient between "IEconomic GDP Average" and "Freedom Average"
GDP = renamed_df.iloc[:,4]
Free = renamed_df.iloc[:,5]
correlation = st.pearsonr(GDP,Free)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.8

# %%
# Compare the calcualted Pearson's r to the plots
plt.scatter(GDP,Free)
plt.xlabel('Region GDP Per Capita')
plt.ylabel('Average Freedom Score Per Region Per Year (L)')
print(f"The correlation between both factors is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between both factors is 0.8

# %%
#  Generate the correlation matrix and find the strongest positive and negative correlations
all_data = renamed_df.corr()
all_data.unstack().sort_values()
# Out:
# Health Average       Generocity Average     0.295864
# Generocity Average   Health Average         0.295864
# Family Average       Generocity Average     0.362768
# Generocity Average   Family Average         0.362768
# Happiness Average    Generocity Average     0.504795
# Economy GDP Average  Generocity Average     0.504795
# Generocity Average   Happiness Average      0.504795
#                      Economy GDP Average    0.504795
# Health Average       Gov Trust Average      0.604764
# Gov Trust Average    Health Average         0.604764
# Freedom Average      Health Average         0.621839
# Health Average       Freedom Average        0.621839
# Gov Trust Average    Family Average         0.676888
# Family Average       Gov Trust Average      0.676888
# Gov Trust Average    Generocity Average     0.736560
# Generocity Average   Gov Trust Average      0.736560
# Family Average       Freedom Average        0.743224
# Freedom Average      Family Average         0.743224
# Gov Trust Average    Freedom Average        0.801031
# Freedom Average      Gov Trust Average      0.801031
# Economy GDP Average  Gov Trust Average      0.803540
# Gov Trust Average    Happiness Average      0.803540
#                      Economy GDP Average    0.803540
# Happiness Average    Gov Trust Average      0.803540
# Freedom Average      Happiness Average      0.804709
# Happiness Average    Freedom Average        0.804709
# Economy GDP Average  Freedom Average        0.804709
# Freedom Average      Economy GDP Average    0.804709
#                      Generocity Average     0.851167
# Generocity Average   Freedom Average        0.851167
# Happiness Average    Health Average         0.894886
# Health Average       Happiness Average      0.894886
# Economy GDP Average  Health Average         0.894886
# Health Average       Economy GDP Average    0.894886
# Family Average       Health Average         0.908176
# Health Average       Family Average         0.908176
# Family Average       Happiness Average      0.947000
#                      Economy GDP Average    0.947000
# Happiness Average    Family Average         0.947000
# Economy GDP Average  Family Average         0.947000
# Happiness Average    Economy GDP Average    1.000000
# Gov Trust Average    Gov Trust Average      1.000000
# Family Average       Family Average         1.000000
# Economy GDP Average  Happiness Average      1.000000
#                      Economy GDP Average    1.000000
# Health Average       Health Average         1.000000
# Generocity Average   Generocity Average     1.000000
# Freedom Average      Freedom Average        1.000000
# Happiness Average    Happiness Average      1.000000
# dtype: float64

# %%
# Perform a linear regression on Generosity versus Economy GDP rate
from scipy import stats
vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(GDP, generosity)

# %%
# Create equation of line to calculate predicted Generosity
vc_fit = vc_slope * GDP + vc_int

# %%
# Plot the linear model on top of scatter plot 
GDP = Comp_data_df.iloc[:,4]
generosity = Comp_data_df.iloc[:,1]
plt.scatter(GDP,generosity)
plt.plot(GDP,vc_fit,"--")
plt.xticks(GDP, rotation=90)
plt.xlabel('GDP')
plt.ylabel('Generosity Rate')
plt.show()

# %%
# Repeat plotting scatter and linear model for GDP versus Family
family_rate = Comp_data_df.iloc[:, 3]
m_slope, m_int, m_r, m_p, m_std_err = stats.linregress(GDP, family_rate)
m_fit = m_slope * GDP + m_int
plt.scatter(GDP,family_rate)
plt.plot(GDP,m_fit,"--")
plt.xticks(GDP, rotation=45)
plt.xlabel('GDP')
plt.ylabel('Family Rate')
plt.show()

# %%
# Repeat plotting scatter and linear model for GDP versus Health
health_rate = Comp_data_df.iloc[:, 2]
aa_slope, aa_int, aa_r, aa_p, aa_std_err = stats.linregress(GDP, health_rate)
aa_fit = aa_slope * GDP + aa_int
plt.scatter(GDP, health_rate)
plt.plot(GDP,aa_fit,"--")
plt.xticks(GDP, rotation=90)
plt.xlabel('GDP')
plt.ylabel('Health Rate')
plt.show()

# %%
# Generate a facet plot of all 3 figures
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
fig.suptitle("GDP Rate", fontsize=16, fontweight="bold")

ax1.set_xlim(min(GDP), max(GDP))
ax1.plot(GDP, generosity, linewidth=1, marker="o")
ax1.plot(GDP, vc_fit, "b--", linewidth=1)
ax1.set_ylabel("Generosity Rate")

ax2.plot(GDP, family_rate, linewidth=1, marker="o", color="r")
ax2.plot(GDP, m_fit, "r--", linewidth=1)
ax2.set_ylabel("Family Rate")

ax3.plot(GDP, health_rate, linewidth=1, marker="o", color="g")
ax3.plot(GDP, aa_fit, "g--", linewidth=1)
ax3.set_ylabel("Health Rate")
ax3.set_xlabel("GDP")

plt.show()

# %%
Comp_data_df.iloc[:, 3]
# Out:
# Region
# Australia and New Zealand          1.424400
# North America                      1.358000
# Western Europe                     1.348270
# Latin America and Caribbean        1.195410
# Eastern Asia                       1.198350
# Central and Eastern Europe         1.174757
# Southeastern Asia                  1.119225
# Middle East and Northern Africa    0.988267
# Southern Asia                      0.803771
# Sub-Saharan Africa                 0.857232
# Name: Family Average, dtype: float64

# %%
df = Comp_data_df.reset_index()
labels = df["Region"]
values = df["Happiness Average"]

# Change the bar colors here
plt.bar(labels, values, color=['red', 'red', 'red', 'red', 'red', 'red', 'blue','red','green','green'])

plt.xticks(rotation=90)
plt.ylim(2, 7.5)

plt.title("Average Happiness Score Per Region")
plt.ylabel('Happiness Score (Avg)')
plt.xlabel('Country')

#Save and Show plot
plt.tight_layout()
plt.savefig("Resources/AverageHappiness_Region.png")
plt.show()

# %%
# Summary of Happiness per year
Happiness_Rank_df = data[["Country", "Region", "Happiness Rank 2015", "Happiness Rank 2016", "Happiness Rank 2017", "Happiness Rank 2018", "Happiness Rank 2019"]]
Happiness_Rank_df = Happiness_Rank_df.groupby("Region")
Happiness_Rank_df.mean()

#Find the averages of the data
Happ_Rank_df = Happiness_Rank_df.mean().reset_index()
Happ_Rank_df["Happiness Average"] = Happ_df.mean(axis=1)
Happ_Rank_df

# Filter the DataFrame down only to those columns to chart
Happiness_Rank_plot = Happ_Rank_df[["Region", "Happiness Average"]]

# Set the index to be "Region" so they will be used as labels
Happiness_Rank_plot = Happiness_Rank_plot.set_index("Region")
Happiness_Rank_plot.head(15)
# Out:
#                                  Happiness Average
# Region
# Australia and New Zealand                 9.100000
# Central and Eastern Europe               75.157143
# Eastern Asia                             71.750000
# Latin America and Caribbean              50.550000
# Middle East and Northern Africa          83.400000
# North America                            11.300000
# Southeastern Asia                        78.200000
# Southern Asia                           112.457143
# Sub-Saharan Africa                      127.625806
# Western Europe                           25.010000

# %%
Happiness_Rank_plot['Rank'] = Happiness_Rank_plot['Happiness Average'].rank()
Happiness_Rank_plot.head(15)
# Out:
#                                  Happiness Average  Rank
# Region
# Australia and New Zealand                 9.100000   1.0
# Central and Eastern Europe               75.157143   6.0
# Eastern Asia                             71.750000   5.0
# Latin America and Caribbean              50.550000   4.0
# Middle East and Northern Africa          83.400000   8.0
# North America                            11.300000   2.0
# Southeastern Asia                        78.200000   7.0
# Southern Asia                           112.457143   9.0
# Sub-Saharan Africa                      127.625806  10.0
# Western Europe                           25.010000   3.0

# %%
rank_df = Comp_data_df
rank_df["World Rank"] = rank_df["Economy GDP Average"].rank(ascending=False)
rank_df.head(15)
#Comp_data_df.head(15)
# Out:
#                                  Gov Trust Average  Generocity Average  \
# Region
# Australia and New Zealand                 0.357200            0.424500
# North America                             0.223400            0.372400
# Western Europe                            0.225860            0.272250
# Latin America and Caribbean               0.095130            0.180400
# Eastern Asia                              0.079750            0.158000
# Central and Eastern Europe                0.076421            0.154914
# Southeastern Asia                         0.129625            0.388950
# Middle East and Northern Africa           0.135222            0.172911
# Southern Asia                             0.100371            0.300886
# Sub-Saharan Africa                        0.096948            0.209477
#
#                                  Health Average  Family Average  \
# Region
# Australia and New Zealand              0.903100        1.424400
# North America                          0.861200        1.358000
# Western Europe                         0.893450        1.348270
# Latin America and Caribbean            0.688300        1.195410
# Eastern Asia                           0.829050        1.198350
# Central and Eastern Europe             0.695986        1.174757
# Southeastern Asia                      0.650900        1.119225
# Middle East and Northern Africa        0.659667        0.988267
# Southern Asia                          0.513086        0.803771
# Sub-Saharan Africa                     0.302039        0.857232
#
#                                  Economy GDP Average  Freedom Average  \
# Region
# Australia and New Zealand                   7.294600         0.611300
# North America                               7.174700         0.559000
# Western Europe                              6.789330         0.518420
# Latin America and Caribbean                 6.003100         0.456750
# Eastern Asia                                5.514850         0.408150
# Central and Eastern Europe                  5.437643         0.352814
# Southeastern Asia                           5.389475         0.540800
# Middle East and Northern Africa             5.242200         0.334967
# Southern Asia                               4.580657         0.392829
# Sub-Saharan Africa                          4.190935         0.366503
#
#                                  Happiness Average  World Rank
# Region
# Australia and New Zealand                 7.294600         1.0
# North America                             7.174700         2.0
# Western Europe                            6.789330         3.0
# Latin America and Caribbean               6.003100         4.0
# Eastern Asia                              5.514850         5.0
# Central and Eastern Europe                5.437643         6.0
# Southeastern Asia                         5.389475         7.0
# Middle East and Northern Africa           5.242200         8.0
# Southern Asia                             4.580657         9.0
# Sub-Saharan Africa                        4.190935        10.0

# %%
hq = Comp_data_df
hq = hq.sort_values(
    ["Freedom Average", "Family Average"], ascending=False)#.rank(ascending=False)
hq.sort_values(by='World Rank', ascending=True)
# Out:
#                                  Gov Trust Average  Generocity Average  \
# Region
# Australia and New Zealand                 0.357200            0.424500
# North America                             0.223400            0.372400
# Western Europe                            0.225860            0.272250
# Latin America and Caribbean               0.095130            0.180400
# Eastern Asia                              0.079750            0.158000
# Central and Eastern Europe                0.076421            0.154914
# Southeastern Asia                         0.129625            0.388950
# Middle East and Northern Africa           0.135222            0.172911
# Southern Asia                             0.100371            0.300886
# Sub-Saharan Africa                        0.096948            0.209477
#
#                                  Health Average  Family Average  \
# Region
# Australia and New Zealand              0.903100        1.424400
# North America                          0.861200        1.358000
# Western Europe                         0.893450        1.348270
# Latin America and Caribbean            0.688300        1.195410
# Eastern Asia                           0.829050        1.198350
# Central and Eastern Europe             0.695986        1.174757
# Southeastern Asia                      0.650900        1.119225
# Middle East and Northern Africa        0.659667        0.988267
# Southern Asia                          0.513086        0.803771
# Sub-Saharan Africa                     0.302039        0.857232
#
#                                  Economy GDP Average  Freedom Average  \
# Region
# Australia and New Zealand                   7.294600         0.611300
# North America                               7.174700         0.559000
# Western Europe                              6.789330         0.518420
# Latin America and Caribbean                 6.003100         0.456750
# Eastern Asia                                5.514850         0.408150
# Central and Eastern Europe                  5.437643         0.352814
# Southeastern Asia                           5.389475         0.540800
# Middle East and Northern Africa             5.242200         0.334967
# Southern Asia                               4.580657         0.392829
# Sub-Saharan Africa                          4.190935         0.366503
#
#                                  Happiness Average  World Rank
# Region
# Australia and New Zealand                 7.294600         1.0
# North America                             7.174700         2.0
# Western Europe                            6.789330         3.0
# Latin America and Caribbean               6.003100         4.0
# Eastern Asia                              5.514850         5.0
# Central and Eastern Europe                5.437643         6.0
# Southeastern Asia                         5.389475         7.0
# Middle East and Northern Africa           5.242200         8.0
# Southern Asia                             4.580657         9.0
# Sub-Saharan Africa                        4.190935        10.0

# %%
draft = Comparison_data

# %%
draft["World Rank"] = rank_df["Economy GDP Average"].rank(ascending=False)
draft.head()
# Out:
#                              Gov Trust Average  Generocity Average  \
# Region
# Australia and New Zealand                  1.0                 1.0
# North America                              1.0                 1.0
# Western Europe                             1.0                 1.0
# Latin America and Caribbean                1.0                 1.0
# Eastern Asia                               1.0                 1.0
#
#                              Health Average  Happiness Average  World Rank
# Region
# Australia and New Zealand               1.0                1.0         1.0
# North America                           1.0                1.0         2.0
# Western Europe                          1.0                1.0         3.0
# Latin America and Caribbean             1.0                1.0         4.0
# Eastern Asia                            1.0                1.0         5.0

# %%
draft = draft.groupby(
    "Economy GDP Average")["Freedom Average"]["Family Average"] ascending=False).rank(ascending=False)
draft.head(15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-208-fbf13f50a091> in <module>
# ----> 1 draft = draft.groupby(["Economy GDP Average", "Freedom Average", "Family Average"]).rank(ascending=False)
#       2 draft.head(15)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 'Economy GDP Average'

# %%
#p-test 
from scipy.stats import ttest_ind
import numpy as np
gdp_data = Comparison_data["Economy GDP Average"]
happy_data = Comparison_data["Happiness Average"]
ttest,pval = ttest_ind(gdp_data,happy_data)
print("p-value",pval)
# Out:
# p-value 1.0

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import pandas as pd
import scipy.stats as stats

# %%
boxp = Comparison_data
boxp.reset_index()
# Out:
#                             Region  Gov Trust Average  Generocity Average  \
# 0        Australia and New Zealand           0.357200            0.424500
# 1       Central and Eastern Europe           0.076421            0.154914
# 2                     Eastern Asia           0.079750            0.158000
# 3      Latin America and Caribbean           0.095130            0.180400
# 4  Middle East and Northern Africa           0.135222            0.172911
# 5                    North America           0.223400            0.372400
# 6                Southeastern Asia           0.129625            0.388950
# 7                    Southern Asia           0.100371            0.300886
# 8               Sub-Saharan Africa           0.096948            0.209477
# 9                   Western Europe           0.225860            0.272250
#
#    Health Average  Family Average  Economy GDP Average  Freedom Average  \
# 0        0.903100        1.424400             7.294600         0.611300
# 1        0.695986        1.174757             5.437643         0.352814
# 2        0.829050        1.198350             5.514850         0.408150
# 3        0.688300        1.195410             6.003100         0.456750
# 4        0.659667        0.988267             5.242200         0.334967
# 5        0.861200        1.358000             7.174700         0.559000
# 6        0.650900        1.119225             5.389475         0.540800
# 7        0.513086        0.803771             4.580657         0.392829
# 8        0.302039        0.857232             4.190935         0.366503
# 9        0.893450        1.348270             6.789330         0.518420
#
#    Happiness Average
# 0           7.294600
# 1           5.437643
# 2           5.514850
# 3           6.003100
# 4           5.242200
# 5           7.174700
# 6           5.389475
# 7           4.580657
# 8           4.190935
# 9           6.789330

# %%
# Create a boxplot to compare means
Comp_data_df.boxplot("Happiness Average", by="Region", figsize=(20, 10))

# Configure boxplot
fig, ax = plt.subplots()
boxp.boxplot(column=["Gov Trust Average", "Generocity Average", "Health Average", "Family Average", "Freedom Average"], rot = 90, showfliers = False, grid = False)

# Create mask for country Australia
mask = data.Country.str.startswith('Australia', na=False)

# Create a scatterplot using mask
ax.scatter(1, data[mask]["Gov Trust Average"], 
           marker='x', s=200, color='r')
ax.scatter(2, data[mask]["Generocity Average"], 
           marker='x', s=200, color='r')
ax.scatter(3, data[mask]["Health Average"], 
           marker='x', s=200, color='r')
ax.scatter(4, data[mask]["Family Average"], 
           marker='x', s=200, color='r')
ax.scatter(5, data[mask]["Freedom Average"], 
           marker='x', s=200, color='r')
plt.title("How Does Australia Compare?")
plt.savefig("Images/australia_characteristics.png", bbox_inches="tight")
plt.show()
# Out:
# <AxesSubplot:title={'center':'Happiness Average'}, xlabel='Region'>
